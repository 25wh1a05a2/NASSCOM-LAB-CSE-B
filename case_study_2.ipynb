# %% [markdown]
# INTEGRATED CASE STUDY ASSIGNMENT
#
# Student Performance Analysis Using Python, NumPy, Pandas, Data Visualization,
#
# Linear Algebra and Calculus
# Basic Level – Integrated Data Analysis Assignment
#
# 1. Case Study Background
# A college wants to analyze the academic performance of its students and understand how study hours,
# attendance, assignment scores, and previous academic performance influence the final examination score.
# Students are required to use Python programming and basic mathematical concepts to perform a complete
# analysis.
#
# 2. Learning Objectives
#  Use Python to create and manipulate a small dataset.
#  Use Pandas for data loading, filtering, summarization and analysis.
#  Use NumPy for numerical and matrix operations.
#  Create meaningful visualizations using Matplotlib or Seaborn.
#  Represent a real-world problem using matrices and basic linear algebra.
#  Apply differentiation and integration to a simple performance model.
#  Interpret numerical and graphical results and communicate findings clearly.
#
# 3. Dataset
# Student Study_Hours Attendance Assignment_Scor
#
# e
#
# Previous_Scor
# e
#
# Final_Score
# S1 2 65 55 58 60
# S2 3 70 60 62 64
# S3 4 75 65 68 70
# S4 5 80 72 70 75
# S5 6 85 78 76 82
# S6 7 90 85 82 88
# S7 8 92 88 86 91
# S8 4 78 70 72 74
# S9 6 88 80 79 84
# S10 9 95 92 90 94
# Students may enter the above data manually into a Python dictionary or CSV file and then create a Pandas
# DataFrame.
#
# 4. Part A – Python Programming
# Task 1: Create the dataset and display basic information.
# 1. Create the dataset using Python.
# 2. Display the number of students.
# 3. Display the column names.
# 4. Display the data types.
# 5. Display the first five records.
#
# 6. Display the last five records.
# Suggested functions: print(), len(), type(), head(), tail(), info().
#
# 5. Part B – Pandas Data Analysis
# Task 2: Use Pandas to perform the following operations:
# 7. Create a DataFrame from the dataset.
# 8. Display the complete dataset.
# 9. Calculate the average Study Hours, Attendance, Assignment Score, Previous Score and Final Score.
# 10. Find the student with the highest Final Score.
# 11. Find the student with the lowest Final Score.
# 12. Display students whose Attendance is greater than 80%.
# 13. Display students whose Final Score is greater than 80.
# 14. Use describe() to obtain a statistical summary.
#
# 6. Part C – NumPy Numerical Analysis
# Task 3: Extract Final_Score as a NumPy array and calculate:
#  Mean
#  Median
#  Maximum
#  Minimum
#  Standard deviation
# Question: What does the standard deviation tell us about variation in the final scores?
#
# 7. Part D – Data Visualization
# Create at least four visualizations:
# Study Hours vs Final Score: Create a scatter plot. Comment on the visible relationship.
# Attendance vs Final Score: Create a scatter plot. Comment on the visible relationship.
# Distribution of Final Scores: Create a histogram. Comment on the distribution.
# Student-wise Final Scores: Create a bar chart. Identify the highest and lowest scores.
#
# 8. Part E – Linear Algebra
# Consider Study Hours, Attendance and Assignment Score as input variables. Construct the matrix X for all
# students:
# X = [Study_Hours, Attendance, Assignment_Score]
# For example, for S1: X₁ = [2, 65, 55]. For all students, X becomes a 10 × 3 matrix.
# Task 5:
#
# 15. Create matrix X using NumPy.
# 16. Find the shape of X.
# 17. Calculate the transpose Xᵀ.
# 18. Calculate XᵀX.
# 19. Calculate the dot product between Study Hours and Final Score.
# Suggested code:
# X = df[[&quot;Study_Hours&quot;, &quot;Attendance&quot;, &quot;Assignment_Score&quot;]].values
# print(&quot;Shape:&quot;, X.shape)
# print(&quot;Transpose:&quot;)
# print(X.T)
# print(&quot;X transpose X:&quot;)
# print(X.T @ X)
# Question: Why is matrix representation useful when several variables are analyzed together?
#
# 9. Part F – Calculus: Differentiation
# Suppose the predicted final score is represented by the function:
# F(x) = 40 + 5x − 0.2x²
# where x represents study hours.
# Task 6:
# 20. Find dF/dx manually.
# 21. Show that F′(x) = 5 − 0.4x.
# 22. Find the value of x for which F′(x) = 0.
# 23. Interpret the result in the context of study hours.
# Suggested Python verification:
# def F(x):
# return 40 + 5*x - 0.2*x**2
# def dF(x):
# return 5 - 0.4*x
# for x in range(1, 11):
# print(x, F(x), dF(x))
#
# 10. Part G – Calculus: Integration
# Suppose the learning benefit is represented by:
# L(x) = 5x − 0.2x²
# Task 7: Calculate ∫₀⁵ L(x) dx.
#
# 24. Solve the integral manually.
# 25. Implement a numerical approximation using Python.
# 26. Explain what the area under the curve represents in this case.
#
# 11. Part H – Correlation Analysis
# Calculate the correlation between:
#  Study Hours and Final Score
#  Attendance and Final Score
#  Assignment Score and Final Score
#  Previous Score and Final Score
# Suggested code:
# print(df.corr(numeric_only=True))
# Create a correlation heatmap.
# Question: Which variable has the strongest relationship with Final Score? Support your answer using the
# calculated correlation values.
#
# 12. Part I – Mini Prediction Model Using Linear Algebra
# Construct a simple linear model:
# Y = b₀ + b₁X₁ + b₂X₂ + b₃X₃
# where Y = Final Score, X₁ = Study Hours, X₂ = Attendance and X₃ = Assignment Score.
# Using matrix notation:
# Y = Xβ
# Estimate the coefficients using:
# β = (XᵀX)⁻¹XᵀY
# Suggested NumPy implementation:
# X = df[[&quot;Study_Hours&quot;, &quot;Attendance&quot;, &quot;Assignment_Score&quot;]].values
# Y = df[&quot;Final_Score&quot;].values
# X = np.column_stack((np.ones(len(X)), X))
# beta = np.linalg.inv(X.T @ X) @ X.T @ Y
# print(&quot;Coefficients:&quot;)
# print(beta)
# Students should explain, in simple words, what the estimated coefficients indicate about the relationship
# between the input variables and final score.
#
# 13. Part J – Final Interpretation
# 27. What is the average final score?
# 28. How much variation is present in the final scores?
# 29. Which student obtained the highest final score?
# 30. What relationship do you observe between study hours and final score?
# 31. What relationship do you observe between attendance and final score?
# 32. Which variable has the strongest correlation with final score?
# 33. Why is matrix representation useful for multiple input variables?
# 34. What does the derivative represent in the study-hours model?
# 35. What does the area under the learning-benefit curve represent?
# 36. What are the main conclusions from the complete analysis?
# Write the final conclusion in approximately 5–7 sentences.
#
# 14. Expected Deliverables
#  Python source file (.py) or Jupyter Notebook (.ipynb).
#  Generated graphs/visualizations.
#  A short report containing observations and conclusions.
#  Mathematical calculations for the differentiation, integration and matrix operations.
#  Final prediction-model coefficients with interpretation.

# %% [markdown]
# Part A - Python Programming

# %%
import pandas as pd
import numpy as np
data = {
    "Student": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"],
    "Study_Hours": [2, 3, 4, 5, 6, 7, 8, 4, 6, 9],
    "Attendance": [65, 70, 75, 80, 85, 90, 92, 78, 88, 95],
    "Assignment_Score": [55, 60, 65, 72, 78, 85, 88, 70, 80, 92],
    "Previous_Score": [58, 62, 68, 70, 76, 82, 86, 72, 79, 90],
    "Final_Score": [60, 64, 70, 75, 82, 88, 91, 74, 84, 94]
}
print("--- PART A: BASIC INFORMATION ---")
print("Number of students:", len(data["Student"]))
print("Column Names:", list(data.keys()))
df_temp = pd.DataFrame(data)
print("\nData Types:\n", df_temp.dtypes)
print("\nFirst 5 Records:\n", df_temp.head())
print("\nLast 5 Records:\n", df_temp.tail())

# %% [markdown]
# Part B – Pandas Data Analysis

# %%
df = pd.DataFrame(data)
print("1. Complete Dataset:\n", df)
print("\n2. Column Averages:")
print(df.mean(numeric_only=True))
print("\n3. Highest Final Score Student:")
print(df.loc[df['Final_Score'].idxmax()])
print("\n4. Lowest Final Score Student:")
print(df.loc[df['Final_Score'].idxmin()])
print("\n5. Students with Attendance > 80%:")
print(df[df['Attendance'] > 80])
print("\n6. Students with Final Score > 80:")
print(df[df['Final_Score'] > 80])
print("\n7. Statistical Summary:")
print(df.describe())

# %% [markdown]
# PART-C:NUMPY NUMERICAL ANALYSIS

# %%
final_scores=df["Final_Score"].to_numpy()
print("Mean:",np.mean(final_scores))
print("Median:",np.median(final_scores))
print("Maximum:",np.max(final_scores))
print("Minimum:",np.min(final_scores))
print("Standard Deviation:",np.std(final_scores))

# %% [markdown]
# PART-D:DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
plt.scatter(df['Study_Hours'],df['Final_Score'],color='blue')
plt.title('Study Hours vs Final Score')
plt.xlabel('Study HOurs')
plt.ylabel('Final Score')
plt.grid(True)
plt.subplot(2,2,2)
plt.scatter(df['Attendance'],df['Final_Score'],color='green')
plt.title('Attendance vs Final Score')
plt.xlabel('Attendance (%)')
plt.ylabel('Final Score')
plt.grid(True)
plt.subplot(2,2,3)
plt.hist(df['Final_Score'],bins=10,color='orange',edgecolor='black')
plt.title('Distribution of Final Scores')
plt.xlabel('Final Score')
plt.ylabel('Frequency')
plt.subplot(2,2,4)
plt.bar(df['Student'],df['Final_Score'],color='red',edgecolor='black')
plt.title('Student-wise Final Scores')
plt.xlabel('Student')
plt.ylabel('Final Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# PART-E:LINEAR ALGEBRA

# %%
x=df[["Study_Hours","Attendance","Assignment_Score"]].values
print("1.Matrix x (10x3):\n",x)
print("2.Shape of x:",x.shape)
print("3.Transpose(x^T):\n",x.T)
print("4.x^T @ x:\n",x.T@x)
dot_product=np.dot(df["Study_Hours"].values,df["Final_Score"].values)
print("5.Dot Product between Study Hours and Final Score:",dot_product)

# %% [markdown]
# PART-F:CALCULUS-DIFFERENTIATION

# %%
def f(x):
  return 40+5*x-0.2*x**2
def df(x):
  return 5-0.4*x
print("Study Hours(x) | Predicted Score f(x) | Derivative df(x)")
print("-"*55)
for x in range(1,11):
  print(f"{x:15d} | {f(x):19.2f} | {df(x):16.2f}")

# %% [markdown]
# PART-G:CALCULUS- INTEGRATION

# %%
from scipy.integrate import quad
def L(x):
    return 5*x - 0.2*x**2
area, error = quad(L, 0, 5)

print("--- PART G: INTEGRATION ---")
print(f"Area under L(x) from 0 to 5 (Numerical Integration): {area:.4f}")

# %% [markdown]
# PART-H:CORRELATION ANALYSIS

# %%
df=pd.DataFrame(data)
corr_matrix = df.corr(numeric_only=True)

print("--- PART H: CORRELATION ANALYSIS ---")
print("Correlation Matrix:\n", corr_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', fmt=".3f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# PART-I:MINI PREDICTION MODEL USING LINEAR ALGEBRA

# %%
df = pd.DataFrame(data)
X_inputs = df[["Study_Hours", "Attendance", "Assignment_Score"]].values
Y = df["Final_Score"].values
X_design = np.column_stack((np.ones(len(X_inputs)), X_inputs))
beta = np.linalg.inv(X_design.T @ X_design) @ X_design.T @ Y
print("--- PART I: PREDICTION MODEL ---")
print("Estimated Coefficients:")
print(f"b0 (Intercept)       : {beta[0]:.4f}")
print(f"b1 (Study Hours)     : {beta[1]:.4f}")
print(f"b2 (Attendance)      : {beta[2]:.4f}")
print(f"b3 (Assignment Score): {beta[3]:.4f}")

# %% [markdown]
# Average Final Score:  78.20
#
# Variation in Final Scores: Standard deviation is  10.51 , showing a score spread from  60  to  94 .
#
# Highest Performing Student: Student S10 ( 94 ).
#
# Study Hours vs Final Score Relationship: Strong positive linear association ( r=0.985 ).
#
# Attendance vs Final Score Relationship: Strong positive linear association ( r=0.989 ).
#
# Strongest Correlated Variable: Assignment Score ( r=0.995 ).
#
# Utility of Matrix Representation: Vectorizes multivariate calculations into single operations like  (XTX)−1XTY , simplifying mathematical model optimization.
#
# Role of Derivative: Measures rate of score gain per additional study hour ( F′(x) ) and locates optimal study cutoff ( x=12.5  hours).
#
# Role of Definite Integral: Computes total cumulative learning benefit achieved over a specific study time span ( 0  to  5  hours).
